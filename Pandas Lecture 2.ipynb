# %%
import pandas as pd

# %%
data ={
    'state':['ohio','ohio','ohio','Nevada','Nevada','Nevada'],
    'year':[2000,2001,2002,2003,2001,2000],
    'pop':[1.5,1.7,1.3,1,1.8,1.7]
}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    ohio  2000  1.5
# 1    ohio  2001  1.7
# 2    ohio  2002  1.3
# 3  Nevada  2003  1.0
# 4  Nevada  2001  1.8
# 5  Nevada  2000  1.7

# %%
frame = pd.DataFrame(data, columns=['year','state','pop'])
frame
# Out:
#    year   state  pop
# 0  2000    ohio  1.5
# 1  2001    ohio  1.7
# 2  2002    ohio  1.3
# 3  2003  Nevada  1.0
# 4  2001  Nevada  1.8
# 5  2000  Nevada  1.7

# %%
frame = pd.DataFrame(data, columns=['year','state','pop','extra'])
frame
# Out:
#    year   state  pop extra
# 0  2000    ohio  1.5   NaN
# 1  2001    ohio  1.7   NaN
# 2  2002    ohio  1.3   NaN
# 3  2003  Nevada  1.0   NaN
# 4  2001  Nevada  1.8   NaN
# 5  2000  Nevada  1.7   NaN

# %%
frame = pd.DataFrame(data, columns=['year','state','pop','extra'], index = ['a','b','c','d','e','f'])
frame
# Out:
#    year   state  pop extra
# a  2000    ohio  1.5   NaN
# b  2001    ohio  1.7   NaN
# c  2002    ohio  1.3   NaN
# d  2003  Nevada  1.0   NaN
# e  2001  Nevada  1.8   NaN
# f  2000  Nevada  1.7   NaN

# %%
frame['state']
# Out:
# 0      ohio
# 1      ohio
# 2      ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
frame.loc[0]
# Out:
# year     2000
# state    ohio
# pop       1.5
# extra     NaN
# Name: 0, dtype: object

# %%
pop={
    'Nevada':{2001:2.4,2002:2.9},
    'Ohio':{2000:1.5,2001:1.7,2002:3.6}
}
frame1 = pd.DataFrame(pop)
frame1
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
frame1.loc[2000]
# Out:
# Nevada    NaN
# Ohio      1.5
# Name: 2000, dtype: float64

# %%
pd.DataFrame(pop, index=[2001,2002,2003])
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN

# %%
pdata = {
    'ohio': frame1['Ohio'][:-1],
    'Nevada':frame1['Nevada'][:2]
}
pdata
# Out:
# {'ohio': 2000    1.5
#  2001    1.7
#  Name: Ohio, dtype: float64, 'Nevada': 2000    NaN
#  2001    2.4
#  Name: Nevada, dtype: float64}

# %%
k = pd.DataFrame(pdata)
k
# Out:
#       ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4

# %%
frame1.index.name = 'year'; frame1.columns.name='state'
frame1
# Out:
# state  Nevada  Ohio
# year
# 2000      NaN   1.5
# 2001      2.4   1.7
# 2002      2.9   3.6

# %%
frame1.values
# Out:
# array([[nan, 1.5],
#        [2.4, 1.7],
#        [2.9, 3.6]])

# %% [markdown]
# # 5.2 Essential Functionality
# Reindexing

# %%
 obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
 obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
 obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
 obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(["blue","purple","red"], index=[0,2,4])
obj3
# Out:
# 0      blue
# 2    purple
# 4       red
# dtype: object

# %%
obj3.reindex(range(5))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4       red
# dtype: object

# %%
obj3.reindex(range(6))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4       red
# 5       NaN
# dtype: object

# %%
obj3.reindex(range(6),method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4       red
# 5       red
# dtype: object

# %%
obj3.reindex(range(6),method="bfill")
# Out:
# 0      blue
# 1    purple
# 2    purple
# 3       red
# 4       red
# 5       NaN
# dtype: object

# %%
obj3.reindex(range(6),fill_value=0)
# Out:
# 0      blue
# 1         0
# 2    purple
# 3         0
# 4       red
# 5         0
# dtype: object

# %%
obj3.reindex(['a','b','c'], fill_value=0)
# Out:
# a    0
# b    0
# c    0
# dtype: object

# %% [markdown]
# # Reindexing of frames

# %%
import numpy as np
f1 = pd.DataFrame(np.arange(9).reshape((3, 3)), index=['a', 'c', 'd'], columns=['Ohio', 'Texas', 'California'])
f1
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2 = frame.reindex(['a', 'b', 'c', 'd'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states = ['Texas', 'Utah', 'California']
frame2.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a    1.0   NaN         2.0
# b    NaN   NaN         NaN
# c    4.0   NaN         5.0
# d    7.0   NaN         8.0

# %%
frame2.reindex(index=['f','b','a','d','c','g'],columns=['Texas','New York','Utah','California','New Mexico'])
# Out:
#    Texas  New York  Utah  California  New Mexico
# f    NaN       NaN   NaN         NaN         NaN
# b    NaN       NaN   NaN         NaN         NaN
# a    1.0       NaN   NaN         2.0         NaN
# d    7.0       NaN   NaN         8.0         NaN
# c    4.0       NaN   NaN         5.0         NaN
# g    NaN       NaN   NaN         NaN         NaN

# %%
d1 = pd.DataFrame(np.arange(1,16).reshape((3,5)), columns=['a','b','c','d','e'])
d1
# Out:
#     a   b   c   d   e
# 0   1   2   3   4   5
# 1   6   7   8   9  10
# 2  11  12  13  14  15

# %%
d2 = pd.DataFrame(np.arange(1,101).reshape((20,5)), columns=['a','b','c','d','e'], index=range(1,101,5))
d2
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
list('abcde')
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
frame2.loc['c']['California']
# Out:
# 5.0

# %%
frame2.loc['c']
# Out:
# Ohio          3.0
# Texas         4.0
# California    5.0
# Name: c, dtype: float64

# %%
frame2.iloc[::-1]
# Out:
#    Ohio  Texas  California
# d   6.0    7.0         8.0
# c   3.0    4.0         5.0
# b   NaN    NaN         NaN
# a   0.0    1.0         2.0

# %%
frame2.iloc[::-1,::-1]
# Out:
#    California  Texas  Ohio
# d         8.0    7.0   6.0
# c         5.0    4.0   3.0
# b         NaN    NaN   NaN
# a         2.0    1.0   0.0

# %%
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame2.loc['a':'c']frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0

# %%
frame2.iloc[0:3]
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0

# %%
frame2.loc['b']['Ohio'] = 2
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   2.0    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame2.loc['b'][0] = 1
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   1.0    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame2.loc['b'][0:2] = [4,5]
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    5.0         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame2.loc['b'][0]
# Out:
# 4.0

# %%
frame2.loc['b'][[0,2]]
# Out:
# Ohio          4.0
# California    NaN
# Name: b, dtype: float64

# %%
frame2.loc['b'][[2,0]] = frame2.loc['b'][[0,2]]
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    5.0         4.0
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
frame2['Ohio'][1]
# Out:
# nan

# %%
frame2['Ohio'][1] + 5
# Out:
# nan

# %%
frame4 = frame2.copy()
frame4['std'] = [4,5,6,7]
frame4
# Out:
#    Ohio  Texas  California  std
# a   0.0    1.0         2.0    4
# b   NaN    5.0         4.0    5
# c   3.0    4.0         5.0    6
# d   6.0    7.0         8.0    7

# %%
frame2 + frame4
# Out:
#    California  Ohio  Texas  std
# a         4.0   0.0    2.0  NaN
# b         8.0   NaN   10.0  NaN
# c        10.0   6.0    8.0  NaN
# d        16.0  12.0   14.0  NaN

# %%
frame4-frame2
# Out:
#    California  Ohio  Texas  std
# a         0.0   0.0    0.0  NaN
# b         0.0   NaN    0.0  NaN
# c         0.0   0.0    0.0  NaN
# d         0.0   0.0    0.0  NaN

# %%
frame2.loc[:'d':2]
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# c   3.0    4.0         5.0

# %%
frame2.loc['a':'d':-1]
# Out:
# Empty DataFrame
# Columns: [Ohio, Texas, California]
# Index: []

# %%
frame2.loc['a'::-1]
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0

# %%
frame2.loc['d'::-1]
# Out:
#    Ohio  Texas  California
# d   6.0    7.0         8.0
# c   3.0    4.0         5.0
# b   NaN    5.0         4.0
# a   0.0    1.0         2.0

# %%
frame2.loc['d'::-1,::-1]
# Out:
#    California  Texas  Ohio
# d         8.0    7.0   6.0
# c         5.0    4.0   3.0
# b         4.0    5.0   NaN
# a         2.0    1.0   0.0

# %%
frame2.loc[::-1,'Texas']
# Out:
# d    7.0
# c    4.0
# b    5.0
# a    1.0
# Name: Texas, dtype: float64

# %%
frame2.loc[::-1,'Texas':'California']
# Out:
#    Texas  California
# d    7.0         8.0
# c    4.0         5.0
# b    5.0         4.0
# a    1.0         2.0

# %%
frame2.loc[::-1,'Texas'::-1]
# Out:
#    Texas  Ohio
# d    7.0   6.0
# c    4.0   3.0
# b    5.0   NaN
# a    1.0   0.0

# %%
abs(-2)
# Out:
# 2

# %%
frame4[frame4 > 5]
# Out:
#    Ohio  Texas  California  std
# a   NaN    NaN         NaN  NaN
# b   NaN    NaN         NaN  NaN
# c   NaN    NaN         NaN  6.0
# d   6.0    7.0         8.0  7.0

# %%
frame4[frame4.isna()]
# Out:
#    Ohio  Texas  California  std
# a   NaN    NaN         NaN  NaN
# b   NaN    NaN         NaN  NaN
# c   NaN    NaN         NaN  NaN
# d   NaN    NaN         NaN  NaN

# %%
frame4.isna()
# Out:
#     Ohio  Texas  California    std
# a  False  False       False  False
# b   True  False       False  False
# c  False  False       False  False
# d  False  False       False  False

# %%
frame4.fillna(0)
# Out:
#    Ohio  Texas  California  std
# a   0.0    1.0         2.0    4
# b   0.0    5.0         4.0    5
# c   3.0    4.0         5.0    6
# d   6.0    7.0         8.0    7

# %%
frame4
# Out:
#    Ohio  Texas  California  std
# a   0.0    1.0         2.0    4
# b   NaN    5.0         4.0    5
# c   3.0    4.0         5.0    6
# d   6.0    7.0         8.0    7

# %%
frame4.fillna(0, inplace=True)

# %%
frame4
# Out:
#    Ohio  Texas  California  std
# a   0.0    1.0         2.0    4
# b   0.0    5.0         4.0    5
# c   3.0    4.0         5.0    6
# d   6.0    7.0         8.0    7

# %%
csvData = pd.read_csv('data.csv')
csvData.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
csvData[csvData['Best of Quizzes']>7]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# ...

# %%
csvData[csvData['Best of Quizzes']>7].count()
# Out:
# Student Code            23
# Degree                  23
# Student Name            23
# Mid                     23
# Quiz 1                  23
# Quiz 2                  23
# Best of Quizzes         23
# Assignment 1            22
# Assignment 2            16
# Best of Assignments     23
# Total Sessional (50)    23
# Final (50)              23
# Total (100)             23
# Grade                   23
# dtype: int64

# %%
csvData[(csvData['Best of Quizzes']>7) & (csvData['Best of Assignments']>7)]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# 27  022-14-110452  BS(CS)             Muhammad Osama Khan   27     8.0
# ...

# %%
csvData[(csvData['Best of Quizzes']>7) & (csvData['Best of Assignments']>7)].count()
# Out:
# Student Code            21
# Degree                  21
# Student Name            21
# Mid                     21
# Quiz 1                  21
# Quiz 2                  21
# Best of Quizzes         21
# Assignment 1            20
# Assignment 2            15
# Best of Assignments     21
# Total Sessional (50)    21
# Final (50)              21
# Total (100)             21
# Grade                   21
# dtype: int64
